# %% [markdown]
# 筛选和排序数据

# %% [markdown]
# 数据1：https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv

# %% [markdown]
# 步骤1.导入必要的库

# %%
import pandas as pd

# %% [markdown]
# 步骤2.从该https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv导入数据集。如果无法访问请从自行下载并上传到data目录并导入
#
# 步骤3.将其分配给名为Chipo的变量。

# %%
chipo=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')

# %% [markdown]
# 步骤4.多少种产品的价格超过$ 10.00？

# %%
chipo.loc[chipo['item_price'].str.replace('$','').astype(float)>10,:].shape[0]
# Out:
# 1130

# %% [markdown]
# 步骤5.每件商品的价格是多少？
#
# > 打印只有两列item_name和item_price的数据框

# %%
chipo[['item_name','item_price']]
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# 5                              Chicken Bowl    $10.98
# 6                             Side of Chips     $1.69
# 7                             Steak Burrito    $11.75
# 8                          Steak Soft Tacos     $9.25
# 9                             Steak Burrito     $9.25
# 10                      Chips and Guacamole     $4.45
# 11                     Chicken Crispy Tacos     $8.75
# 12                       Chicken Soft Tacos     $8.75
# 13                             Chicken Bowl    $11.25
# 14                      Chips and Guacamole     $4.45
# 15    Chips and Tomatillo-Green Chili Salsa     $2.39
# ...

# %% [markdown]
# 步骤6.按项目名称排序

# %%
chipo.sort_values(by=['item_name'])
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# 3422      1373         1  6 Pack Soft Drink
# 553        230         1  6 Pack Soft Drink
# 1916       774         1  6 Pack Soft Drink
# 1922       776         1  6 Pack Soft Drink
# 1937       784         1  6 Pack Soft Drink
# 3836      1537         1  6 Pack Soft Drink
# 298        129         1  6 Pack Soft Drink
# 1976       798         1  6 Pack Soft Drink
# 1167       481         1  6 Pack Soft Drink
# 3875      1554         1  6 Pack Soft Drink
# 1124       465         1  6 Pack Soft Drink
# 3886      1558         1  6 Pack Soft Drink
# 2108       849         1  6 Pack Soft Drink
# 3010      1196         1  6 Pack Soft Drink
# 4535      1803         1  6 Pack Soft Drink
# ...

# %% [markdown]
# 步骤7.订购的最昂贵商品的数量是多少？

# %%
chipo.loc[chipo['item_price'].str.replace('$','').astype(float)==chipo['item_price'].str.replace('$','').astype(float).max(),:]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 3598    $44.25

# %% [markdown]
# 步骤8.订购蔬菜沙拉碗几次？

# %%
veg_dic=dict(chipo.groupby('item_name').size())
veg_dic.get('Veggie Salad Bowl')
# Out:
# 18

# %% [markdown]
# 步骤9.人们订购了不止一罐汽水的次数？

# %%
chipo.loc[(chipo['item_name']=='Bottled Water') & (chipo['quantity']>1),:].shape[0]
# Out:
# 23

# %% [markdown]
# 数据2：2012欧洲杯数据

# %% [markdown]
# 步骤1.导入必要的库

# %%
import pandas as pd
from zipfile import ZipFile

# %% [markdown]
# 步骤2.从该https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv导入数据集。如果无法访问请从data目录中导入
#
# 步骤3.将其分配给名为euro12的变量。

# %%
myzip=ZipFile('data/data21580/data.zip')
f=myzip.open('Euro_2012_stats_TEAM.csv')
euro12=pd.read_csv(f,sep=',')
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# 步骤4.仅选择目标列。

# %%
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# 步骤5.有多少团队参加了Euro2012？

# %% [markdown]
# 步骤6.数据集中的列数是多少？

# %%
euro12.shape[0]
# Out:
# 16

# %% [markdown]
# 步骤7.仅查看“团队”，“黄牌”和“红牌”列，并将它们分配给称为学科的数据框

# %%
subject=pd.DataFrame( euro12[['Team','Yellow Cards','Red Cards']])

# %% [markdown]
# 骤8.按红牌对团队进行排序，然后按黄牌进行排序

# %%
subject.sort_values(by=['Red Cards','Yellow Cards'],ascending=False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# 步骤9.计算每个团队给出的平均黄牌

# %%
subject['Yellow Cards'].mean()
# Out:
# 7.4375

# %% [markdown]
# 步骤10.筛选得分超过6的团队

# %%
euro12.loc[euro12['Goals']>6,:]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored      ...       Saves made  Saves-to-shots ratio  \
# 5                      0      ...               10                 62.6%
# 13                     0      ...               15                 93.8%
#
#     Fouls Won Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  \
# 5          63             49        12             4          0       15
# 13        102             83        19            11          0       17
#
#     Subs off  Players Used
# 5         15            17
# ...

# %% [markdown]
# 步骤11.选择以G开头的团队

# %%
euro12.loc[euro12['Team'] like G%,:]
# Out:
#   File "<ipython-input-24-26252502cbdd>", line 1
#     euro12.loc[euro12['Team'] like G%,:]
#                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# 步骤12。选择前7列

# %%
euro12.iloc[:,0:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# 步骤13.选择除最后3个以外的所有列

# %% [markdown]
# 第14步。仅介绍英格兰，意大利和俄罗斯的射门准确性
